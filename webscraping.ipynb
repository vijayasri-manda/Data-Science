# %%
d1 = {'name': ['ram', 'arjun'],
      'age' : [20,30]}

# %%
print(d1)
# Out:
# {'name': ['ram', 'arjun'], 'age': [20, 30]}

# %%
import pandas as pd
d = pd.DataFrame(d1)

# %%
print(d)
# Out:
#     name  age
# 0    ram   20
# 1  arjun   30

# %% [markdown]
# #web Scraping:
# It is a process of extracting data from websites.
# By using Beautifulsoup,scrapy and selenium to scrape any website.

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)')

# %%
print(df)
# Out:
# [   Season     Episodes              Originally released                   \
#    Season     Episodes   Episodes.1      First released    Last released
# 0       1           13           13   December 17, 1989     May 13, 1990
# 1       2           22           22    October 11, 1990    July 11, 1991
# 2       3           24           24  September 19, 1991  August 27, 1992
# 3       4           22           22  September 24, 1992     May 13, 1993
# 4       5           22           22  September 30, 1993     May 19, 1994
# 5       6           25           25   September 4, 1994     May 21, 1995
# 6       7           25           25  September 17, 1995     May 19, 1996
# 7       8           25           25    October 27, 1996     May 18, 1997
# 8       9           25           25  September 21, 1997     May 17, 1998
# 9      10           23           23     August 23, 1998     May 16, 1999
# 10     11           22           22  September 26, 1999     May 21, 2000
# ...

# %%
len(df)
# Out:
# 24

# %%
df[1]
# Out:
#     No. overall  No. in season                                Title  \
# 0             1              1  "Simpsons Roasting on an Open Fire"
# 1             2              2                    "Bart the Genius"
# 2             3              3                    "Homer's Odyssey"
# 3             4              4      "There's No Disgrace Like Home"
# 4             5              5                   "Bart the General"
# 5             6              6                       "Moaning Lisa"
# 6             7              7           "The Call of the Simpsons"
# 7             8              8                  "The Telltale Head"
# 8             9              9              "Life on the Fast Lane"
# 9            10             10                  "Homer's Night Out"
# 10           11             11                "The Crepes of Wrath"
# 11           12             12                 "Krusty Gets Busted"
# 12           13             13             "Some Enchanted Evening"
#
# ...

# %%
df[10]
# Out:
#     No. overall  No. in season  \
# 0         204.0            1.0
# 1         205.0            2.0
# 2         206.0            3.0
# 3         207.0            4.0
# 4         207.0            4.0
# 5         207.0            4.0
# 6           NaN            NaN
# 7         208.0            5.0
# 8         209.0            6.0
# 9         210.0            7.0
# 10        211.0            8.0
# 11        212.0            9.0
# 12        213.0           10.0
# 13        214.0           11.0
# 14        215.0           12.0
# 15        216.0           13.0
# 16        217.0           14.0
# 17        218.0           15.0
# 18        219.0           16.0
# 19        220.0           17.0
# 20        221.0           18.0
# 21        221.0           18.0
# 22        221.0           18.0
# 23          NaN            NaN
# 24        222.0           19.0
# 25        223.0           20.0
# 26        224.0           21.0
# 27        225.0           22.0
# 28        226.0           23.0
#
# ...

# %%
df = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/E0.csv")

# %%
df
# Out:
#     Div        Date   Time          HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  11/08/2023  20:00           Burnley       Man City     0     3   A
# 1    E0  12/08/2023  12:30           Arsenal  Nott'm Forest     2     1   H
# 2    E0  12/08/2023  15:00       Bournemouth       West Ham     1     1   D
# 3    E0  12/08/2023  15:00          Brighton          Luton     4     1   H
# 4    E0  12/08/2023  15:00           Everton         Fulham     0     1   A
# ..   ..         ...    ...               ...            ...   ...   ...  ..
# 375  E0  19/05/2024  16:00    Crystal Palace    Aston Villa     5     0   H
# 376  E0  19/05/2024  16:00         Liverpool         Wolves     2     0   H
# 377  E0  19/05/2024  16:00             Luton         Fulham     2     4   A
# 378  E0  19/05/2024  16:00          Man City       West Ham     3     1   H
# 379  E0  19/05/2024  16:00  Sheffield United      Tottenham     0     3   A
#
# ...

# %%
df.rename(columns={'FTHG': 'HomeGoals', 'FTAG': 'AwayGoals'}, inplace=True)

# %%
df
# Out:
#     Div        Date   Time          HomeTeam       AwayTeam  HomeGoals  \
# 0    E0  11/08/2023  20:00           Burnley       Man City          0
# 1    E0  12/08/2023  12:30           Arsenal  Nott'm Forest          2
# 2    E0  12/08/2023  15:00       Bournemouth       West Ham          1
# 3    E0  12/08/2023  15:00          Brighton          Luton          4
# 4    E0  12/08/2023  15:00           Everton         Fulham          0
# ..   ..         ...    ...               ...            ...        ...
# 375  E0  19/05/2024  16:00    Crystal Palace    Aston Villa          5
# 376  E0  19/05/2024  16:00         Liverpool         Wolves          2
# 377  E0  19/05/2024  16:00             Luton         Fulham          2
# 378  E0  19/05/2024  16:00          Man City       West Ham          3
# 379  E0  19/05/2024  16:00  Sheffield United      Tottenham          0
#
#      AwayGoals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  \
# ...

# %%
# !pip install "camelot-py[cv]"
# Out:
# ...
# WARNING: camelot-py 1.0.0 does not provide the extra 'cv'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 51.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 77.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 3.3 MB/s eta 0:00:00
# ...

# %%
import camelot as cl
t = cl.read_pdf('https://www.uww.edu/documents/aaec/academic-success/Weekly-Schedule-Template.pdf', pages='1')
# Out:
# /usr/local/lib/python3.11/dist-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from this module in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
t
# Out:
# <TableList n=1>

# %%
df1 = cl.read_pdf("https://www.w3.org/WAI/WCAG21/working-examples/pdf-table/table.pdf")

# %%
df1
# Out:
# <TableList n=1>

# %%
df1[0]
# Out:
# <Table shape=(6, 6)>

# %%
df1[0].df.head()
# Out:
#                        0             1                    2  \
# 0  Disability \nCategory  Participants  Ballots \nCompleted
# 1
# 2                  Blind             5                    1
# 3             Low Vision             5                    2
# 4              Dexterity             5                    4
#
#                                     3                         4  \
# 0  Ballots \nIncomplete/ \nTerminated                   Results
# 1                                                      Accuracy
# 2                                   4                34.5%, n=1
# 3                                   3  98.3% n=2 \n(97.7%, n=3)
# 4                                   1                98.3%, n=4
#
#                                  5
# 0
# 1               Time to \ncomplete
# 2                    1199 sec, n=1
# 3  1716 sec, n=3 \n(1934 sec, n=2)
# 4                  1672.1 sec, n=4

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#    age  gender  miles   debt  income  sales
# 0   28       0     23      0    4099    620
# 1   26       0     27      0    2677   1792
# 2   30       1     58  41576    6215  27754
# 3   26       1     25  43172    7626  28256
# 4   20       1     17   6979    8071   4438

# %%
df.head(10)
# Out:
#    age  gender  miles   debt  income  sales
# 0   28       0     23      0    4099    620
# 1   26       0     27      0    2677   1792
# 2   30       1     58  41576    6215  27754
# 3   26       1     25  43172    7626  28256
# 4   20       1     17   6979    8071   4438
# 5   58       1     18      0    1262   2102
# 6   44       1     17    418    7017   8520
# 7   39       1     28      0    3282    500
# 8   44       0     24  48724    9980  22997
# 9   46       1     46  57827    8163  26517

# %%
df.tail()
# Out:
#      age  gender  miles   debt  income  sales
# 958   22       0     11   8778    9829   1593
# 959   19       1     23   4850    3470   4742
# 960   28       1     28   9312    2720  12771
# 961   50       0     29  51343    8713  28511
# 962   47       1     15   3735    6406   6104

# %%
len(df)
# Out:
# 963

# %%
df.describe()
# Out:
#               age      gender       miles          debt        income  \
# count  963.000000  963.000000  963.000000    963.000000    963.000000
# mean    37.971963    0.512980   27.704050  14109.004154   6176.047767
# std     12.290838    0.500091   13.378181  18273.702481   3260.670142
# min     19.000000    0.000000   10.000000      0.000000      0.000000
# 25%     27.000000    0.000000   20.000000   1475.000000   3506.500000
# 50%     37.000000    1.000000   25.000000   6236.000000   6360.000000
# 75%     49.000000    1.000000   32.000000  16686.000000   8649.500000
# max     60.000000    1.000000   97.000000  59770.000000  11970.000000
#
#               sales
# count    963.000000
# mean   11689.860852
# std     8986.896921
# min      500.000000
# 25%     3554.000000
# 50%     9130.000000
# 75%    19245.000000
# max    29926.000000

# %%
df.isnull().sum()
# Out:
# age       0
# gender    0
# miles     0
# debt      0
# income    0
# sales     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 963 entries, 0 to 962
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     963 non-null    int64
#  1   gender  963 non-null    int64
#  2   miles   963 non-null    int64
#  3   debt    963 non-null    int64
#  4   income  963 non-null    int64
#  5   sales   963 non-null    int64
# dtypes: int64(6)
# memory usage: 45.3 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['miles'].unique()
# Out:
# array([23, 27, 58, 25, 17, 18, 28, 24, 46, 14, 22, 47, 34, 33, 11, 30, 10,
#        15, 31, 32, 29, 21, 38, 16, 20, 26, 48, 35, 36, 39, 42, 50, 88, 80,
#        19, 89, 41, 45, 68, 49, 13, 53, 12, 43, 44, 75, 78, 85, 92, 51, 79,
#        40, 93, 37, 94, 84, 97, 82, 95, 70, 72, 67, 77, 62, 87])

# %%
df['debt'].unique()
# Out:
# array([    0, 41576, 43172,  6979,   418, 48724, 57827,  2595, 33119,
#         3517,  1543,  9362,  3596, 58481,  3410,  2822,   247,  7254,
#        41258, 43708,  8045,   263,  1971, 47277, 59138, 56500,  9882,
#          751, 50167,  4342,  4133,  7134,  5503,   166,  6114,  2389,
#         3899,  3992,  5110,  7375,  9592,  8590, 23918,  8020, 47753,
#         9310,  3001,  5044,    72,  1123, 22992,  2398, 53432,  8549,
#        58742, 10293,  6551, 30534,  1383,  5397, 16366, 54167,    73,
#          596, 53232,    67,  5313, 50583, 55591,  5844,  2394,  4307,
#        52146,   733,  6900,  1802,  7475, 51363, 11100, 45577, 56372,
#        40218,  5214,  5274, 44112, 41178,  8816,  9703,  4169, 40933,
#        25184, 43107, 16241, 30660,  8746,  5015, 50310,  3212,  8017,
#         7730, 25462,  2014, 49859,  4829, 53965, 12650,   787,  5856,
#        55494,  8801,  7205, 17091,  7530,  9898, 18335,    91,   529,
# ...

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='gender',hue = 'gender' ,data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
plt.figure(figsize=(30,10))
sns.countplot(x='miles',hue = 'miles' ,data=df)
# Out:
# <Axes: xlabel='miles', ylabel='count'>

# %%
plt.figure(figsize = (30,10))
sns.countplot(x = 'miles',data = df, hue = 'gender')
# Out:
# <Axes: xlabel='miles', ylabel='count'>
